# %%
from playsound import playsound
playsound('/Users/CTR/Desktop/SeniorDesign/Audio-Classification/ESC-50-master/audio/audio1.wav')

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys


spf = wave.open("/Users/CTR/Desktop/SeniorDesign/Audio-Classification/ESC-50-master/audio/audio1.wav", "r")

# Extract Raw Audio from Wav File
signal = spf.readframes(-1)
signal = np.fromstring(signal, "Int16")
fs = spf.getframerate()

# If Stereo
if spf.getnchannels() == 2:
    print("Just mono files")
    sys.exit(0)


Time = np.linspace(0, len(signal) / fs, num=len(signal))

plt.figure(1)
plt.title("Signal Wave...")
plt.plot(Time, signal)
plt.show()
# Out:
# /Users/CTR/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   # This is added back by InteractiveShellApp.init_path()
# /Users/CTR/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   # This is added back by InteractiveShellApp.init_path()

# %%
import IPython.display as ipd
ipd.Audio("/Users/CTR/Desktop/SeniorDesign/Audio-Classification/ESC-50-master/audio/audio1.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
